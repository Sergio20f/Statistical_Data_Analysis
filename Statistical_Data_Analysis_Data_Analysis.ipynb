# %% [markdown]
# # Statistical Data Analysis: Data Analysis Assignment
#
# - Statistical Data Analysis (SPA6328)
# - Academic Year: 2020-2021
# - Module Organiser: Dr Seth Zenz
# - Module Associate: Prof Adrian Bevan
#
#
# ## This assessment is for formative feedback.
#
# In this assignment you will perform data analysis tasks building on your understanding of Python. We will be using data from the scikit-learn (sklearn) package to give you access to real-world data examples to explore. The purpose of this task is to enable you to numerically and visually study the data, applying methodologies that you have learned in this module.
#
# The sklearn package is documented online at https://scikit-learn.org/stable/. The package has useful data loading tools documented at https://scikit-learn.org/stable/datasets/index.html. We are interested in exploring the following data:
#
# - <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris">iris data set</a> (for classificaiton)
#
# This example starts by studying the iris classification problem to help you understand the values and distributions of the data set features. There are tasks assugned to allow you to extend your understanding of this data.
#
# ## Information about the data set
#
# The iris data is described as a "toy" sample of data. There are other data sets also collected from real-world publications over time, and the iris data has an advantage that it has a limited number of examples (i.e. entries) and a limited number of features (i.e. variables) to understand. So this is a good sample to start with. This assignment is the first in a set of assignments that will lead up to you working on a machine learining problem. You may need to review your notes on Python from your 1st year Professional Skills for Scientists module to refresh your recollection of the programming language.
#
# When we start working on a new problem it is important that we learning as much as possible about the data and the context of the problem as possible. The iris data is accessed by calling the load_iris function. The way that we are going to call this function results in a return value of something called a "<a href="https://scikit-learn.org/stable/modules/generated/sklearn.utils.Bunch.html">Bunch</a>". A bunch is similar to a Python dictonary in that it has key-value pairs. The bunch has the following keys:
#
# - <b>data</b>: These are the data, and each row is described by some number of dimensions M. There are M columns, one for each of these dimensions or features. This is a numpy array with the shape (N, M), where N is the number of examples and M is the number of features.
# - <b>target</b>: these are the true values for the example (one row per example). This is a numpy array with shape (N). For now it is sufficient to understand that the target values are known values (either labels for some type of example, or some known value). We will discuss how these are used in machine learning later in the course.
# - <b>feature_names</b>: this is a list of the names of the features in the data. This is a numpy array with shape (M)
# - <b>filename</b>: [not available for all of the data sets] this is the name of the data file that is being used. This is a string.
# - <b>DESCR</b>: this is a description of the data. This is a string that includes contextual information on the data sample that is worth reading and understanding. The DESCR value also includes references of where the data came from, so that if there are aspects of the data set or problem domain that you don't understand or want to learn more about, that you have a starting point of where to begin.
#
# Having loaded the data we will make 1D plots of the data (as histograms). The purpose of this is to understand the shape of the distributions in case there are interesting discriminating features. The distribution of target values (the type of iris: setosa, versicolor, virginica) is also plotted. Having done this step, you will have a task to work through. There are additional suggested data sets for you to explore.
#
# ## Task
#
# Study the iris data in detail by working through this notebook. You should
#  1) Add your name and student number to the jypyter notebook in the second cell in the jupyter notebook.
#  2) Review the data description to understand (i) the source of the data (ii) the variables used to describe the data (iii) the different types of iris that the data describe.
#  3) Familiarise yourself with the 1D plots of each of the features.
#  4) Review the covariance and correlation matrices, along with the means and widths of the variables, as calculated.
#  5) Make 2D scatter plots for these data to compare pairs of variables against each other.
#  6) Repeat the above, making a new file to study each of the three types of iris, one type at a time, or alternatively all three on the same plot (in which case colour coding and a legend are required to be able to distinguish the types).
#  7) Download your 4 notebooks and submit this for assessment using QMplus.  Before you submit, remember to run your notebook one last time and check the output to ensure that you are submitting the right version. Use the naming convention SDA_IRIS_StudentID_1.ipybn, through SDA_IRIS_StudentID_4.ipybn (or just two submissions if you have plotted all 3 types against each other).

# %% [markdown]
#  * Name:        Sergio Alfonso Calvo Ordoñez
#  * Student ID:  190865179

# %%
"""
The data sets wer are using come from sklearn.  We need matplotlib for plotting out scatter plots and histograms,
and we will be using numpy to compute covaraince and correlation matrices. So all three are imported at the
start of this notebook.
"""
print("Import the sklearn datasets")
import sklearn.datasets as ds
import matplotlib.pyplot as plt
import numpy as np

"""
The Iris data is to be used for the default study.  There are other suggested data sets that can be accessed
by commenting out the Iris data lines, and uncommenting the corresponding lines for one of the other data sets.
"""
#print("use the Boston house price data")
#Bunch = ds.load_boston(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
#target_name = "MEDV"
#target_plot_xaxis = "target value (house prices, MEDVAL $k US)"

#print("use the brest cancer data")
#Bunch = ds.load_breast_cancer(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
#target_name = "disease progression"
#target_plot_xaxis = "target value (Malignant=0, Benign=1)"

#print("use the diabetes data")
#Bunch = ds.load_diabetes(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
#target_name = "disease progression"
#target_plot_xaxis = "target value (disease progression)"

print("use the iris data")
Bunch = ds.load_iris(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
target_name = "class"
target_plot_xaxis = "target value (class)"

#print("use the linnerud(exercise) data")
#Bunch = ds.load_linnerud(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
#target_name = "class"
#target_plot_xaxis = "target value (class)"

#print("use the wine data")
#Bunch = ds.load_wine(return_X_y=False) # we want to get the Bunch so that we can access more than just the data and target values
#target_name = "class"
#target_plot_xaxis = "target value (class)"


# Print the description of the data
print(Bunch.DESCR)
#print("The following data file is being used: ", Bunch.filename, "\n")

# no need to print the feature names as these are printed out with DESCR 
# print(Bunch.feature_names)

# un-comment hte following lines to print out the data and the target values.
# 
# print(Bunch.data)
# print(Bunch.target)

i=0
for this_feature in Bunch.feature_names:
    print("Working on feature", this_feature)
    plt.hist(Bunch.data[:,i], 10)
    plt.xlabel(this_feature)
    plt.ylabel("Number of entries")
    plt.show()
    i+=1   # increment the counter to acces the next feature

print("Working on the target values")
plt.hist(Bunch.target, 10)
plt.xlabel(target_plot_xaxis) # use the value set above when selecting the data set
plt.ylabel("Number of entries")
plt.show()
# Out:
# Import the sklearn datasets
# use the iris data
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# ...

# %%
"""
Compute the mean and standard deviation of the data set, formatted to a certain
number of decimal places. Note that some data sets will have this information 
as a part of the description printed out as a result of runnign the previous code
cell
"""
print("-------------------------------------------------------------")
print("Variable       \t        Average \t St Dev ")
print("-------------------------------------------------------------")

for i in range(len(Bunch.feature_names)):
    print("{0:15s} \t {1:5.3f}    \t {2:5.3f}".format(Bunch.feature_names[i], np.average(Bunch.data[:,i]), np.std(Bunch.data[:,i])))
print("{0:15s} \t {1:5.3f}    \t {2:5.3f}".format(target_name, np.average(Bunch.target), np.std(Bunch.target)))

print("-------------------------------------------------------------")


"""
Now compute the covariance matrix and print that out.  Note that the sklearn data samples
use rows for examples and columns for features. The default numpy correlation calculation
is to use rows for features and columns for examples; so we have to set rowvar=False to
reverse that default ordering to get the correct matrix.
"""
cov_matrix = np.cov(Bunch.data, rowvar=False)
print("\nThe covariance matrix for these data is:\n")
print(cov_matrix)

"""
Also compute the correlation matrix; again need to use the rowvar=False option
"""
corr_matrix = np.corrcoef(Bunch.data, rowvar=False)
print("\nThe correlation matrix for these data is:\n")
print(corr_matrix)
# Out:
# -------------------------------------------------------------
# Variable       	        Average 	 St Dev
# -------------------------------------------------------------
# sepal length (cm) 	 5.843    	 0.825
# sepal width (cm) 	 3.057    	 0.434
# petal length (cm) 	 3.758    	 1.759
# petal width (cm) 	 1.199    	 0.760
# class           	 1.000    	 0.816
# -------------------------------------------------------------
#
# The covariance matrix for these data is:
#
# [[ 0.68569351 -0.042434    1.27431544  0.51627069]
#  [-0.042434    0.18997942 -0.32965638 -0.12163937]
#  [ 1.27431544 -0.32965638  3.11627785  1.2956094 ]
#  [ 0.51627069 -0.12163937  1.2956094   0.58100626]]
#
# The correlation matrix for these data is:
#
# [[ 1.         -0.11756978  0.87175378  0.81794113]
#  [-0.11756978  1.         -0.4284401  -0.36612593]
#  [ 0.87175378 -0.4284401   1.          0.96286543]
#  [ 0.81794113 -0.36612593  0.96286543  1.        ]]

# %% [markdown]
# ## Task: Extend the study of these data
#
# The 1D distributions of the features of the data, and of the target values have been plotted.  Metrics related to these have been quantified and the covariance and correlation matrices between the features of the data have been computed.  These are linear correlations, and there may be information in the form of non-linear correlations that can be missed from a linear plot.
#
#  1) Make 2D scatter plots for these data to compare pairs of variables against each other.
#
#  2) Repeat the above step, but plotting the different classes of data in different colours, either one per notebook, or all three together on the same plots, using a legend to highlight the different data types.

# %%
Bunch.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
Bunch['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
sepal_length = Bunch['data'][:, :1]
sepal_width = Bunch['data'][:, 1:2]
petal_length = Bunch['data'][:, 2:3]
petal_width = Bunch['data'][:, 3:4]

# %%
fig, ax1 = plt.subplots(3, 2, figsize=(10, 10))
fig.tight_layout(pad=4)

# Sepal length vs Sepal width
ax1[0][0].scatter(sepal_width, sepal_length)
ax1[0][0].set_title("Sepal length vs Sepal width")
ax1[0][0].set(xlabel="sepal width (cm)", ylabel="sepal length (cm)")

# Petal length vs Sepal width
ax1[0][1].scatter(sepal_width, petal_length)
ax1[0][1].set_title("Petal length vs Sepal width")
ax1[0][1].set(xlabel="sepal width (cm)", ylabel="petal length (cm)")

# Petal width vs Sepal width
ax1[1][0].scatter(sepal_width, petal_width)
ax1[1][0].set_title("Sepal width vs Petal width")
ax1[1][0].set(xlabel="sepal width (cm)", ylabel="petal width (cm)")

# Petal length vs Sepal length
ax1[1][1].scatter(sepal_length, petal_length)
ax1[1][1].set_title("Sepal length vs Petal length")
ax1[1][1].set(xlabel="sepal length (cm)", ylabel="petal length (cm)")

# Petal length vs Sepal length
ax1[2][0].scatter(sepal_length, petal_width)
ax1[2][0].set_title("Sepal length vs Petal width")
ax1[2][0].set(xlabel="sepal length (cm)", ylabel="petal width (cm)")

# Petal length vs Sepal length
ax1[2][1].scatter(petal_length, petal_width)
ax1[2][1].set_title("Petal width vs Petal length")
ax1[2][1].set(xlabel="petal length (cm)", ylabel="petal length (cm)")
# Out:
# [Text(0.5, 69.0, 'petal length (cm)'),
#  Text(367.48863636363626, 0.5, 'petal length (cm)')]

# %%
Bunch['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='blue', lw=4)]

new_data = [(Bunch['data'][i], Bunch['target'][i]) for i in range(len(Bunch['data']))]
fig, ax = plt.subplots(3, 2, figsize=(10, 10))
fig.tight_layout(pad=4)

for idx, i in enumerate(new_data):
    if i[1] == 0:
        c = 'red'
        ax[0][0].scatter(sepal_width[idx], sepal_length[idx], c=c)
        ax[0][1].scatter(sepal_width[idx], petal_length[idx], c=c)
        ax[1][0].scatter(sepal_width[idx], petal_width[idx], c=c)
        ax[1][1].scatter(sepal_length[idx], petal_length[idx], c=c)
        ax[2][0].scatter(sepal_length[idx], petal_width[idx], c=c)
        ax[2][1].scatter(petal_length[idx], petal_width[idx], c=c)
        
    elif i[1] == 1:
        c = 'green'
        ax[0][0].scatter(sepal_width[idx], sepal_length[idx], c=c)
        ax[0][1].scatter(sepal_width[idx], petal_length[idx], c=c)
        ax[1][0].scatter(sepal_width[idx], petal_width[idx], c=c)
        ax[1][1].scatter(sepal_length[idx], petal_length[idx], c=c)
        ax[2][0].scatter(sepal_length[idx], petal_width[idx], c=c)
        ax[2][1].scatter(petal_length[idx], petal_width[idx], c=c)
    else:
        c = 'blue'
        ax[0][0].scatter(sepal_width[idx], sepal_length[idx], c=c)
        ax[0][1].scatter(sepal_width[idx], petal_length[idx], c=c)
        ax[1][0].scatter(sepal_width[idx], petal_width[idx], c=c)
        ax[1][1].scatter(sepal_length[idx], petal_length[idx], c=c)
        ax[2][0].scatter(sepal_length[idx], petal_width[idx], c=c)
        ax[2][1].scatter(petal_length[idx], petal_width[idx], c=c)
    
    ax[0][0].set_title("Sepal length vs Sepal width")
    ax[0][0].set(xlabel="sepal width (cm)", ylabel="sepal length (cm)")
    
    ax[0][1].set_title("Petal length vs Sepal width")
    ax[0][1].set(xlabel="sepal width (cm)", ylabel="petal length (cm)")
    
    ax[1][0].set_title("Sepal width vs Petal width")
    ax[1][0].set(xlabel="sepal width (cm)", ylabel="petal width (cm)")
    
    ax[1][1].set_title("Sepal length vs Petal length")
    ax[1][1].set(xlabel="sepal length (cm)", ylabel="petal length (cm)")
    
    ax[2][0].set_title("Sepal length vs Petal width")
    ax[2][0].set(xlabel="sepal length (cm)", ylabel="petal width (cm)")
    
    ax[2][1].set_title("Petal width vs Petal length")
    ax[2][1].set(xlabel="petal length (cm)", ylabel="petal length (cm)")
    
    fig.legend(custom_lines, ['Setosa', 'Versicolor', 'Virginica'])

# %% [markdown]
# ## More data samples to study
#
# If you have completed this task and would like to explore more data sets for different problem domains, then note that there are several additional data sets in the scikit-learn package.  In particular we recommend that you take a look at:
#
#  * <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_boston">Boston house price data set</a> (for regression), function load_boston (house price data)
#  * <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html#sklearn.datasets.load_breast_cancer">breast cancer dataset</a> (for classification), function load_breast_cancer (disease data)
#  * <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html#sklearn.datasets.load_diabetes">diabetes dataset</a> (for regression), function load_diabetes (disease data)
#  * <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_linnerud.html#sklearn.datasets.load_linnerud">linnerud dataset</a> (for regression), function load_linnerud (exercise data)
#  * <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_linnerud.html#sklearn.datasets.load_wine">wine dataset</a> (for regression), function load_wine (wine varietal data)
#
# To change the data being looked at you will need to modify the code above to comment out the iris data set lines and uncomment those  for the corresponding data set.  The digits data set is not recommended for this exercise as it is a set of hand written numbers from 0 to 1 (this is a precursor of the MNIST standard computer science data set).  Note: some of these data sets have a lot of features, and so the number of 2D plots and entries in the covariance matrix will be large.
#
# ## Take home message
#
# Understanding the data (and problem domain) is key to being able to do something useful with the data.  If you cut corners in this step then that will limit your ability to extract information from the data.
#  * The first step to understanding the data is to know what the features available are and what they mean in in the context of the problem.
#  * The second step is to know the distribution of those features.
#  * The third step is to know how the features are related (correlations - both linear and non-linear).
#
# Once these steps have been completed you will be able to use the data with more confidence.  If you don't understand these steps you may miss issues with the data (for example do all features have values for all examples, or are some features missing values?) or spend a lot of time working on a problem without realising there may be opportunities to simplify the analysis and obtain better performance (accuracy, purity etc.) as a result.
